# %% [markdown]
# ## Урок 2. Дискретные случайные величины. Закон распределения вероятностей. Биномиальный закон распределения. Распределение Пуассона

# %% [markdown]
# 1. Вероятность того, что стрелок попадет в мишень, выстрелив один раз, равна 0.8. Стрелок выстрелил 100 раз. Найдите вероятность того, что стрелок попадет в цель ровно 85 раз.
# 2. Вероятность того, что лампочка перегорит в течение первого дня эксплуатации, равна 0.0004. В жилом комплексе после ремонта в один день включили 5000 новых лампочек. Какова вероятность, что ни одна из них не перегорит в первый день? Какова вероятность, что перегорят ровно две?
# 3. Монету подбросили 144 раза. Какова вероятность, что орел выпадет ровно 70 раз?
# 4. В первом ящике находится 10 мячей, из которых 7 - белые. Во втором ящике - 11 мячей, из которых 9 белых. Из каждого ящика вытаскивают случайным образом по два мяча. Какова вероятность того, что все мячи белые? Какова вероятность того, что ровно два мяча белые? Какова вероятность того, что хотя бы один мяч белый?

# %%
import pandas as pd
import numpy as np
from math import factorial as fl

# %% [markdown]
# ### Задача 1
#
# $$P_n(X=k) = C_n^k p^k q^{n-k}$$
#
# k = 85
#
# n = 100
#
# p = 0.8
#
# q = 1 - p = 1 - 0.8 = 0.2
#
#
# $$P_{100}(X=85) = C_{100}^{85} {0.8}^{85} {0.2}^{100-85} = $$

# %%
P100 = (fl(100) / (fl(85) * fl(100 - 85))) * 0.8 ** 85 * 0.2 ** (100 - 85)
print(f'Вероятность того, что стрелок попадет в мишень ровно 85 раз из 100 = {P100 :.4f}')
# Out:
# Вероятность того, что стрелок попадет в мишень ровно 85 раз из 100 = 0.0481

# %% [markdown]
# ### Задача 2
#
# A - ни одна лампочка не перегорела
#
# $$P(A) = 1 - q ^ n$$

# %%
P = 1 - (1 - 0.0004) ** 5000
print(f'Вероятность того, что ни одна лампочка не перегорит = {P :.3f}')
# Out:
# Вероятность того, что ни одна лампочка не перегорит = 0.865

# %% [markdown]
# ### Задача 3
#
# B - монета выпала 40 раз
#
# n = 144
#
# k = 70
#
# p = 0.5
#
# q = 0.5
#
# $$P_{144}(X=70) = C_{144}^{70} {0.5}^{70} {0.5}^{144-70} = $$

# %%
P144 = (fl(144) / (fl(70) * fl(144 - 70))) * 0.5 ** 70 * 0.5 ** (144 - 70)
print(f'Вероятность того, что орел выпадет ровно 70 раз = {P144 :.4f}')
# Out:
# Вероятность того, что орел выпадет ровно 70 раз = 0.0628

# %% [markdown]
# ### Задача 4
#
# D1 - мячи, которые достали из первого ящика все белые
#
# D2 - мячи, которые достали из второго ящика все белые
#
# D = D1 * D2 - все мячи белые
#
# $$P(D1) =  \frac{C_{7}^{2}}{C_{10}^{2} }$$
#
# $$P(D2) =  \frac{C_{9}^{2}}{C_{11}^{2} }$$
#
# $$P(D) = P(D1)*P(D2)$$

# %%
PD1 = (fl(7) / (fl(2)*fl(7 - 2))) / (fl(10) / (fl(2)*fl(10 - 2)))
PD2 = (fl(9) / (fl(2)*fl(9 - 2))) / (fl(11) / (fl(2)*fl(11 - 2)))
print(f'Вероятность того, что все мячи белые = {PD1 * PD2 :.3f}')
# Out:
# Вероятность того, что все мячи белые = 0.305

# %% [markdown]
# D11 - из первого ящика вынули два белых мяча
#
# D12 - из второго ящика вынули только черные мячи
#
# D21 - из второго ящика вынули два белых мяча
#
# D22 - из первого ящика вынули только черные мячи
#
# D31 - из первого ящика вынули один белый мяч
#
# D32 - из второго ящика вынули один белый мяч
#
# D = D11 D12 + D21 D22 + D31 * D32 - вынули ровно два белых мяча
#
# $$P(D11) =  \frac{C_{7}^{2}}{C_{10}^{2} }$$
#
# $$P(D12) =\frac{C_{2}^{2}}{C_{11}^{2} }$$

# %%
PD11D12 = (fl(7) / (fl(2)*fl(7 - 2))) / (fl(10) / (fl(2)*fl(10 - 2))) * (fl(2) / (fl(2)*fl(2 - 2))) / (fl(11) / (fl(2)*fl(11 - 2)))

# %% [markdown]
# $$P(D21) =\frac{C_{3}^{2}}{C_{10}^{2} }$$
#
# $$P(D22) = \frac{C_{9}^{2}}{C_{11}^{2} }$$

# %%
PD21D22 = (fl(3) / (fl(2)*fl(3 - 2))) / (fl(10) / (fl(2)*fl(10 - 2))) * (fl(9) / (fl(2)*fl(9 - 2))) / (fl(11) / (fl(2)*fl(11 - 2)))

# %% [markdown]
# $$P(D31) =  \frac{C_{7}^{1} * C_{3}^{1}}{C_{10}^{2} }$$
# $$P(D32) =  \frac{C_{9}^{1} * C_{2}^{1}}{C_{11}^{2} }$$

# %%
PD31 = (fl(7) / (fl(1)*fl(7 - 1)) * fl(3)) / (fl(1)*fl(3 - 1)) / (fl(10) / (fl(2)*fl(10 - 2)))
PD32 = (fl(9) / (fl(1)*fl(9 - 1)) * fl(2)) / (fl(1)*fl(2 - 1)) / (fl(11) / (fl(2)*fl(11 - 2)))

# %%
PD = PD11D12 + PD21D22 + PD31 * PD32
print(f'Вероятность того, что достанут ровно два белых мяча = {PD :.3f}')
# Out:
# Вероятность того, что достанут ровно два белых мяча = 0.205

# %%
PD = 1 - (fl(3) / (fl(2)*fl(3 - 2))) / (fl(10) / (fl(2)*fl(10 - 2))) * (fl(2) / (fl(2)*fl(2 - 2))) / (fl(11) / (fl(2)*fl(11 - 2)))
print(f'Вероятность того, что достанут хотя бы один белый мяч = {PD :.3f}')
# Out:
# Вероятность того, что достанут хотя бы один белый мяч = 0.999
